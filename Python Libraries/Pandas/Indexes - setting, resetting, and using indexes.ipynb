# %%
import pandas as pd

# %%
df1=pd.read_csv('C:/Users/dell/Desktop/survey_results_public.csv',index_col='ResponseId')

# %%
df1.head(10)
# df.tail(5)
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 1           I agree                                      None of these
# 2           I agree                     I am a developer by profession
# 3           I agree                     I am a developer by profession
# 4           I agree                     I am a developer by profession
# 5           I agree                     I am a developer by profession
# 6           I agree                     I am a developer by profession
# 7           I agree                     I am a developer by profession
# 8           I agree                     I am a developer by profession
# 9           I agree  I am not primarily a developer, but I write co...
# 10          I agree                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 1           18-24 years old
# 2           25-34 years old
# 3           45-54 years old
# 4           25-34 years old
# ...

# %%
df1.loc[1]
# Out:
# Q120                           I agree
# MainBranch               None of these
# Age                    18-24 years old
# Employment                         NaN
# RemoteWork                         NaN
#                             ...
# ProfessionalTech                   NaN
# Industry                           NaN
# SurveyLength                       NaN
# SurveyEase                         NaN
# ConvertedCompYearly                NaN
# Name: 1, Length: 83, dtype: object

# %%
df1.shape
# Out:
# (89184, 83)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89184 entries, 1 to 89184
# Data columns (total 83 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Q120                                 89184 non-null  object
#  1   MainBranch                           89184 non-null  object
#  2   Age                                  89184 non-null  object
#  3   Employment                           87898 non-null  object
#  4   RemoteWork                           73810 non-null  object
#  5   CodingActivities                     73764 non-null  object
#  6   EdLevel                              87973 non-null  object
#  7   LearnCode                            87663 non-null  object
#  8   LearnCodeOnline                      70084 non-null  object
#  9   LearnCodeCoursesCert                 37076 non-null  object
#  10  YearsCode                            87435 non-null  object
# ...

# %%
pd.set_option('display.max_columns',84)
pd.set_option('display.max_rows',78)

# %%
schema_df = pd.read_csv('C:/Users/dell/Desktop/survey_results_schema.csv',index_col='qname')

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
people = {
    'First':['Corey','Jane','John'],
    'Last':['Schafer','Doe','Doe'],
    'Email':['coreyschafer@gmail.com','Janedoe@gmail.com','Johndoe@gmail.com']
}

# %%
people['Email']
# Out:
# ['coreyschafer@gmail.com', 'Janedoe@gmail.com', 'Johndoe@gmail.com']

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    First     Last                   Email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       Janedoe@gmail.com
# 2   John      Doe       Johndoe@gmail.com

# %%
df['Email']
# Out:
# 0    coreyschafer@gmail.com
# 1         Janedoe@gmail.com
# 2         Johndoe@gmail.com
# Name: Email, dtype: object

# %%
type(df['Email'])
# Out:
# pandas.core.series.Series

# %%
df.Email
# Out:
# 0    coreyschafer@gmail.com
# 1         Janedoe@gmail.com
# 2         Johndoe@gmail.com
# Name: Email, dtype: object

# %%
df[['Last','Email']]
# Out:
#       Last                   Email
# 0  Schafer  coreyschafer@gmail.com
# 1      Doe       Janedoe@gmail.com
# 2      Doe       Johndoe@gmail.com

# %%
df.columns
# Out:
# Index(['First', 'Last', 'Email'], dtype='object')

# %%
df.iloc[0]
# Out:
# First                     Corey
# Last                    Schafer
# Email    coreyschafer@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#    First     Last                   Email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       Janedoe@gmail.com

# %%
df.iloc[[0,1],2]
# Out:
# 0    coreyschafer@gmail.com
# 1         Janedoe@gmail.com
# Name: Email, dtype: object

# %%
df.loc[[0,1],['Email','Last']]
# Out:
#                     Email     Last
# 0  coreyschafer@gmail.com  Schafer
# 1       Janedoe@gmail.com      Doe

# %%
df1.shape
# Out:
# (89184, 83)

# %%
df1.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
df1['Employment'].value_counts()
# Out:
# Employed, full-time                                                                                                                                                                                             53748
# Student, full-time                                                                                                                                                                                               7430
# Independent contractor, freelancer, or self-employed                                                                                                                                                             7076
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                                                         4354
# ...

# %%
# df1.loc[0,'Employment']

# %%
# df1.loc[[0,1,3],'Employment']

# %%
df1.loc[0:2,'Employment']
# Out:
# ResponseId
# 1                    NaN
# 2    Employed, full-time
# Name: Employment, dtype: object

# %%
df1.loc[0:2,'Employment':'EdLevel']
# Out:
#                      Employment RemoteWork  \
# ResponseId
# 1                           NaN        NaN
# 2           Employed, full-time     Remote
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2           Hobby;Contribute to open-source projects;Boots...
#
#                                                  EdLevel
# ResponseId
# 1                                                    NaN
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)

# %%
df.set_index('Email',inplace=True)

# %%
df
# Out:
#                         First     Last
# Email
# coreyschafer@gmail.com  Corey  Schafer
# Janedoe@gmail.com        Jane      Doe
# Johndoe@gmail.com        John      Doe

# %%
df.index
# Out:
# Index(['coreyschafer@gmail.com', 'Janedoe@gmail.com', 'Johndoe@gmail.com'], dtype='object', name='Email')

# %%
df.loc['coreyschafer@gmail.com','Last']
# Out:
# 'Schafer'

# %%
df.iloc[0]
# Out:
# First      Corey
# Last     Schafer
# Name: coreyschafer@gmail.com, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                     Email  First     Last
# 0  coreyschafer@gmail.com  Corey  Schafer
# 1       Janedoe@gmail.com   Jane      Doe
# 2       Johndoe@gmail.com   John      Doe

# %%
schema_df.loc['Employment','question']
# Out:
# 'Which of the following best describes your current employment status? Select all that apply.'

# %%
schema_df.sort_index(ascending=True)
# Out:
#                          qid  \
# qname
# AIAcc                 QID324
# AIBen                 QID316
# AIDev                 QID328
# AINext                QID320
# AIOpen                QID321
# AISearch              QID327
# AISelect              QID314
# AISent                QID315
# AITool                QID319
# Age                   QID127
# BuyNewTool            QID279
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# ICorPM                QID287
# Industry              QID326
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# ...

# %%
schema_df.sort_index(inplace=True)

# %%
##Filtering : & |
# filt=(df['Last']=='Doe') & (df['First']=='John')
filt=(df['Last']=='Schafer') | (df['First']=='John')

# %%
df[filt]
# Out:
#                     Email  First     Last
# 0  coreyschafer@gmail.com  Corey  Schafer
# 2       Johndoe@gmail.com   John      Doe

# %%
df.loc[~filt,'Email']
# Out:
# 1    Janedoe@gmail.com
# Name: Email, dtype: object

# %%
high_salary = (df1['ConvertedCompYearly']>7000)

# %%
df1[high_salary]
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
# 6           I agree  I am a developer by profession  35-44 years old
# ...             ...                             ...              ...
# 89163       I agree  I am a developer by profession  35-44 years old
# 89167       I agree  I am a developer by profession  18-24 years old
# 89168       I agree  I am a developer by profession  18-24 years old
# 89171       I agree  I am a developer by profession  25-34 years old
# 89172       I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df1.loc[high_salary,['Country','LanguageHaveWorkedWith','ConvertedCompYearly']]
# Out:
#                                                       Country  \
# ResponseId
# 2                                    United States of America
# 3                                    United States of America
# 4                                    United States of America
# 5                                                 Philippines
# 6           United Kingdom of Great Britain and Northern I...
# ...                                                       ...
# 89163                                                  Brazil
# 89167                                                 Armenia
# 89168                                                   India
# 89171                                                  France
# 89172                                                  Greece
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 2                                  HTML/CSS;JavaScript;Python
# 3                                  Bash/Shell (all shells);Go
# ...

# %%
countries = ['United States of America','India','Brazil']
filt2=df1['Country'].isin(countries)

# %%
df1.loc[filt2,'Country']
# Out:
# ResponseId
# 2        United States of America
# 3        United States of America
# 4        United States of America
# 7        United States of America
# 8        United States of America
#                    ...
# 89166                       India
# 89168                       India
# 89176    United States of America
# 89179    United States of America
# 89180                      Brazil
# Name: Country, Length: 26314, dtype: object

# %%
filt3=df1['LanguageHaveWorkedWith'].str.contains('Python',na=False)

# %%
df1.loc[filt3,'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                               HTML/CSS;JavaScript;Python
# 8        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10          HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 11                       C#;C++;HTML/CSS;JavaScript;Python
# 12       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89173    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89177    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89181                                 Dart;Java;Python;SQL
# 89182    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object

# %%
df1.rename(columns={'ConvertedCompYearly':'SalaryUSD'},inplace=True)

# %%
df1['RemoteWork'].map({'Remote':True,'Hybrid (some remote, some in-person)':False})
# Out:
# ResponseId
# 1          NaN
# 2         True
# 3        False
# 4        False
# 5         True
#          ...
# 89180     True
# 89181    False
# 89182      NaN
# 89183    False
# 89184    False
# Name: RemoteWork, Length: 89184, dtype: object

# %%
df1['RemoteWork']=df1['RemoteWork'].map({'Remote':True,'Hybrid (some remote, some in-person)':False})

# %%
df1
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# ...

# %%
df1.sort_values(by='Country',inplace=True)

# %%
df1
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 21498       I agree  I am a developer by profession     35-44 years old
# 65293       I agree  I am a developer by profession     35-44 years old
# 1335        I agree  I am a developer by profession     18-24 years old
# 33928       I agree  I am a developer by profession     18-24 years old
# 77723       I agree     I code primarily as a hobby  Under 18 years old
# ...             ...                             ...                 ...
# 88821       I agree                   None of these     35-44 years old
# 88829       I agree                   None of these     25-34 years old
# 88831       I agree                   None of these     18-24 years old
# 89029       I agree                   None of these     45-54 years old
# 89160       I agree                   None of these   Prefer not to say
#
#                                                    Employment RemoteWork  \
# ResponseId
# ...

# %%
df1[['Country','SalaryUSD']].head(70)
# Out:
#                 Country  SalaryUSD
# ResponseId
# 21498       Afghanistan        NaN
# 65293       Afghanistan        NaN
# 1335        Afghanistan     2403.0
# 33928       Afghanistan        NaN
# 77723       Afghanistan        NaN
# 86039       Afghanistan    68000.0
# 10377       Afghanistan        NaN
# 83821       Afghanistan        NaN
# 73714       Afghanistan        NaN
# 61453       Afghanistan        NaN
# 21673       Afghanistan        NaN
# 55302       Afghanistan        NaN
# 62550       Afghanistan        NaN
# 84341       Afghanistan        NaN
# 47692       Afghanistan        NaN
# 2301        Afghanistan        NaN
# 39427       Afghanistan       48.0
# 51789       Afghanistan        NaN
# 76064       Afghanistan        NaN
# 53322       Afghanistan      794.0
# 65337       Afghanistan        NaN
# 82385       Afghanistan        NaN
# 15959       Afghanistan        NaN
# 14420       Afghanistan        NaN
# 53883       Afghanistan        NaN
# ...

# %%
df1.sort_values(by=['Country','SalaryUSD'],ascending=[True,False],inplace=True)

# %%
df1[['Country','SalaryUSD']].head(70)
# Out:
#                 Country  SalaryUSD
# ResponseId
# 88348       Afghanistan  9203683.0
# 86039       Afghanistan    68000.0
# 1335        Afghanistan     2403.0
# 57362       Afghanistan     2288.0
# 17873       Afghanistan     1144.0
# 36049       Afghanistan      915.0
# 53322       Afghanistan      794.0
# 41679       Afghanistan      648.0
# 39427       Afghanistan       48.0
# 37956       Afghanistan       41.0
# 2642        Afghanistan       33.0
# 21498       Afghanistan        NaN
# 65293       Afghanistan        NaN
# 33928       Afghanistan        NaN
# 77723       Afghanistan        NaN
# 10377       Afghanistan        NaN
# 83821       Afghanistan        NaN
# 73714       Afghanistan        NaN
# 61453       Afghanistan        NaN
# 21673       Afghanistan        NaN
# 55302       Afghanistan        NaN
# 62550       Afghanistan        NaN
# 84341       Afghanistan        NaN
# 47692       Afghanistan        NaN
# 2301        Afghanistan        NaN
# ...

# %%
df1['SalaryUSD'].nlargest(10)
# Out:
# ResponseId
# 53269    74351432.0
# 77849    73607918.0
# 66224    72714292.0
# 28122    57513831.0
# 19680    36573181.0
# 55103    17612921.0
# 80587    11000000.0
# 83680    10319366.0
# 47798     9915585.0
# 88348     9203683.0
# Name: SalaryUSD, dtype: float64

# %%
df1.nsmallest(10,'SalaryUSD')
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 47424       I agree  I am a developer by profession  45-54 years old
# 17986       I agree  I am a developer by profession  18-24 years old
# 64956       I agree  I am a developer by profession  45-54 years old
# 63214       I agree  I am a developer by profession  18-24 years old
# 2244        I agree  I am a developer by profession  25-34 years old
# 85525       I agree  I am a developer by profession  35-44 years old
# 41417       I agree  I am a developer by profession  25-34 years old
# 52430       I agree  I am a developer by profession  35-44 years old
# 13709       I agree  I am a developer by profession  25-34 years old
# 87481       I agree  I am a developer by profession  18-24 years old
#
#                                          Employment RemoteWork  \
# ResponseId
# 47424                           Employed, full-time       True
# ...

# %%
df1['SalaryUSD'].head(15)
# Out:
# ResponseId
# 88348    9203683.0
# 86039      68000.0
# 1335        2403.0
# 57362       2288.0
# 17873       1144.0
# 36049        915.0
# 53322        794.0
# 41679        648.0
# 39427         48.0
# 37956         41.0
# 2642          33.0
# 21498          NaN
# 65293          NaN
# 33928          NaN
# 77723          NaN
# Name: SalaryUSD, dtype: float64
