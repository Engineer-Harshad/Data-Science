# %%
import pandas as pd 
import requests 
from bs4 import BeautifulSoup

# %%
# webpage = requests.get('https://books.toscrape.com/').text
# soup = BeautifulSoup(webpage,'lxml')
# # print(soup.prettify())
# # soup.find_all('h1')[0].text

# # len(soup.find_all('p'))

# # len(soup.find_all('p', class_='price_color'))
# books = soup.find_all('li', class_="col-xs-6 col-sm-4 col-md-3 col-lg-3")
# name = []
# price = []
# stock = []
# for book in books:
#     name.append(book.find('h3').text.strip())
#     str = book.find('p', class_="price_color").text.strip()
#     s = slice(2,7)
#     price.append(str[s])
#     stock.append(book.find('p', class_="instock availability").text.strip())

# d = {'Name':name, 'Price':price, 'Stock':stock}
# df = pd.DataFrame(d)
# df

# %%
final = pd.DataFrame()
for b in range(1,10):
    url = "https://books.toscrape.com/catalogue/page-{}.html".format(b)
    webpage = requests.get(url).text
    soup = BeautifulSoup(webpage,'lxml')
    books = soup.find_all('li', class_="col-xs-6 col-sm-4 col-md-3 col-lg-3")
    name = []
    price = []
    stock = []
    for book in books:
        name.append(book.find('h3').text.strip())
        str = book.find('p', class_="price_color").text.strip()
        s = slice(2,7)
        price.append(str[s])
        stock.append(book.find('p', class_="instock availability").text.strip())
    d = {'Name':name, 'Price':price, 'Stock':stock}
    df = pd.DataFrame(d)
    final = final.append(df, ignore_index=True)
final
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6520\3261764291.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_6520\3261764291.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_6520\3261764291.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_6520\3261764291.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_6520\3261764291.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_6520\3261764291.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_6520\3261764291.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_6520\3261764291.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_6520\3261764291.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
#                              Name  Price     Stock
# 0              A Light in the ...  51.77  In stock
# 1              Tipping the Velvet  53.74  In stock
# 2                      Soumission  50.10  In stock
# 3                   Sharp Objects  47.82  In stock
# 4    Sapiens: A Brief History ...  54.23  In stock
# ..                            ...    ...       ...
# 175  Poses for Artists Volume ...  41.06  In stock
# 176     Poems That Make Grown ...  14.19  In stock
# 177             Nightingale, Sing  38.28  In stock
# 178       Night Sky with Exit ...  41.05  In stock
# 179                  Mrs. Houdini  30.25  In stock
#
# [180 rows x 3 columns]
